# %%
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "combine.settings")
import django
django.setup()

# import some ipython displays
from IPython.display import display, HTML

# import core models
from core.models import *

# %%
j = Job.objects.get(pk=25)

# %%
df = j.get_output_as_dataframe()
# Out:
# [DEBUG] 2017-10-14 15:56:45,241 core.models.refresh_from_livy (237): job/statement not found, setting status to gone
# [DEBUG] 2017-10-14 15:56:45,304 core.models.get_output_as_dataframe (313): cyavro read time: 0.05355095863342285

# %%
display(df)
# Out:
#                                               document  \
# 0    <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 1    <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 2    <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 3    <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 4    <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 5    <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 6    <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 7    <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 8    <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 9    <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 10   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 11   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 12   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 13   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 14   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 15   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 16   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 17   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 18   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 19   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 20   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 21   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 22   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 23   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 24   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 25   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 26   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 27   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 28   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 29   <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# ..                                                 ...
# 970  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 971  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 972  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 973  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 974  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 975  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 976  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 977  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 978  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 979  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 980  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 981  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 982  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 983  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 984  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 985  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 986  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 987  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 988  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 989  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 990  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 991  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 992  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 993  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 994  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 995  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 996  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 997  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 998  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
# 999  <record xmlns:xsi="http://www.w3.org/2001/XMLS...
#
#                                                     id  \
# 0    oai:digital.library.wayne.educombine_test:oai:...
# 1    oai:digital.library.wayne.educombine_test:oai:...
# 2    oai:digital.library.wayne.educombine_test:oai:...
# 3    oai:digital.library.wayne.educombine_test:oai:...
# 4    oai:digital.library.wayne.educombine_test:oai:...
# 5    oai:digital.library.wayne.educombine_test:oai:...
# 6    oai:digital.library.wayne.educombine_test:oai:...
# 7    oai:digital.library.wayne.educombine_test:oai:...
# 8    oai:digital.library.wayne.educombine_test:oai:...
# 9    oai:digital.library.wayne.educombine_test:oai:...
# 10   oai:digital.library.wayne.educombine_test:oai:...
# 11   oai:digital.library.wayne.educombine_test:oai:...
# 12   oai:digital.library.wayne.educombine_test:oai:...
# 13   oai:digital.library.wayne.educombine_test:oai:...
# 14   oai:digital.library.wayne.educombine_test:oai:...
# 15   oai:digital.library.wayne.educombine_test:oai:...
# 16   oai:digital.library.wayne.educombine_test:oai:...
# 17   oai:digital.library.wayne.educombine_test:oai:...
# 18   oai:digital.library.wayne.educombine_test:oai:...
# 19   oai:digital.library.wayne.educombine_test:oai:...
# 20   oai:digital.library.wayne.educombine_test:oai:...
# 21   oai:digital.library.wayne.educombine_test:oai:...
# 22   oai:digital.library.wayne.educombine_test:oai:...
# 23   oai:digital.library.wayne.educombine_test:oai:...
# 24   oai:digital.library.wayne.educombine_test:oai:...
# 25   oai:digital.library.wayne.educombine_test:oai:...
# 26   oai:digital.library.wayne.educombine_test:oai:...
# 27   oai:digital.library.wayne.educombine_test:oai:...
# 28   oai:digital.library.wayne.educombine_test:oai:...
# 29   oai:digital.library.wayne.educombine_test:oai:...
# ..                                                 ...
# 970  oai:digital.library.wayne.educombine_test:oai:...
# 971  oai:digital.library.wayne.educombine_test:oai:...
# 972  oai:digital.library.wayne.educombine_test:oai:...
# 973  oai:digital.library.wayne.educombine_test:oai:...
# 974  oai:digital.library.wayne.educombine_test:oai:...
# 975  oai:digital.library.wayne.educombine_test:oai:...
# 976  oai:digital.library.wayne.educombine_test:oai:...
# 977  oai:digital.library.wayne.educombine_test:oai:...
# 978  oai:digital.library.wayne.educombine_test:oai:...
# 979  oai:digital.library.wayne.educombine_test:oai:...
# 980  oai:digital.library.wayne.educombine_test:oai:...
# 981  oai:digital.library.wayne.educombine_test:oai:...
# 982  oai:digital.library.wayne.educombine_test:oai:...
# 983  oai:digital.library.wayne.educombine_test:oai:...
# 984  oai:digital.library.wayne.educombine_test:oai:...
# 985  oai:digital.library.wayne.educombine_test:oai:...
# 986  oai:digital.library.wayne.educombine_test:oai:...
# 987  oai:digital.library.wayne.educombine_test:oai:...
# 988  oai:digital.library.wayne.educombine_test:oai:...
# 989  oai:digital.library.wayne.educombine_test:oai:...
# 990  oai:digital.library.wayne.educombine_test:oai:...
# 991  oai:digital.library.wayne.educombine_test:oai:...
# 992  oai:digital.library.wayne.educombine_test:oai:...
# 993  oai:digital.library.wayne.educombine_test:oai:...
# 994  oai:digital.library.wayne.educombine_test:oai:...
# 995  oai:digital.library.wayne.educombine_test:oai:...
# 996  oai:digital.library.wayne.educombine_test:oai:...
# 997  oai:digital.library.wayne.educombine_test:oai:...
# 998  oai:digital.library.wayne.educombine_test:oai:...
# 999  oai:digital.library.wayne.educombine_test:oai:...
#
#                                           recordSource          setIds
# 0    {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 1    {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 2    {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 3    {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 4    {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 5    {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 6    {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 7    {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 8    {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 9    {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 10   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 11   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 12   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 13   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 14   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 15   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 16   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 17   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 18   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 19   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 20   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 21   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 22   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 23   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 24   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 25   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 26   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 27   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 28   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# 29   {'text': None, 'queryParams': {'endpoint': 'ht...  [combine_test]
# ..                                                 ...             ...
# 970  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 971  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 972  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 973  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 974  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 975  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 976  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 977  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 978  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 979  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 980  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 981  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 982  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 983  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 984  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 985  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 986  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 987  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 988  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 989  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 990  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 991  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 992  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 993  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 994  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 995  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 996  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 997  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 998  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
# 999  {'text': None, 'queryParams': {'metadataPrefix...  [combine_test]
#
# [1000 rows x 4 columns]

# %%
df_html = df.to_html()
print(df_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>document</th>
#       <th>id</th>
#       <th>recordSource</th>
#       <th>setIds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>76</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>83</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>87</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>88</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>90</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>92</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>93</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>94</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>100</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>101</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>102</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>103</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>104</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>105</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>106</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>107</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>108</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>109</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>110</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>111</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>112</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>113</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>114</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>115</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>116</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>117</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>118</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>119</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>120</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>121</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>122</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>123</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>124</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>125</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>126</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>127</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>128</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>129</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>130</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>131</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>132</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>133</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>134</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>135</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>136</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>137</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>138</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>139</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>140</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>141</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>142</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>143</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>144</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>145</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>146</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>147</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>148</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>149</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>150</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>151</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>152</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>153</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>154</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>155</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>156</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>157</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>158</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>159</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>160</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>161</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>162</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>163</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>164</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>165</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>166</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>167</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>168</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>169</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>170</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>171</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>172</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>173</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>174</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>175</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>176</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>177</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>178</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>179</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'endpoint': 'ht...</td>
#       <td>[combine_test]</td>
#     </tr>
# ...
#     </tr>
#     <tr>
#       <th>940</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>941</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>942</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>943</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>944</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>945</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>946</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>947</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>948</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>949</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>950</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>951</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>952</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>953</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>954</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>955</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>956</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>957</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>958</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>959</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>960</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>961</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>962</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>963</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>964</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>965</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>966</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>967</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>968</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>969</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>970</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>971</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>972</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>973</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>974</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>975</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>976</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>977</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>978</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>979</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>980</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>981</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>982</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>983</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>984</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>985</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>986</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>987</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>988</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>989</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>990</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>991</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>992</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>993</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>994</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>995</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>996</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>997</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>998</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#     <tr>
#       <th>999</th>
#       <td>&lt;record xmlns:xsi="http://www.w3.org/2001/XMLS...</td>
#       <td>oai:digital.library.wayne.educombine_test:oai:...</td>
#       <td>{'text': None, 'queryParams': {'metadataPrefix...</td>
#       <td>[combine_test]</td>
#     </tr>
#   </tbody>
# </table>
